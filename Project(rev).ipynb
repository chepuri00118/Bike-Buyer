# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\USER\\Desktop\\data set'

# %%
os.chdir("C:/Users/USER/Desktop/data set")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\USER\\Desktop\\data set'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# bikebuyer=pd.read_csv("bikebuyer2.csv")

# %%
bikebuyer
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %%
#describing the relationships among the features
bikebuyer.describe()
# Out:
#                  ID  Yearly Income     Children         Cars  \
# count   6996.000000    6997.000000  6979.000000  6997.000000
# mean   17744.435249   57020.151493     1.111621     1.586823
# std     4337.428859   32080.449720     1.600912     1.146782
# min        2.000000       0.000000     0.000000     0.000000
# 25%    14249.750000   30000.000000     0.000000     1.000000
# 50%    17406.500000   60000.000000     0.000000     2.000000
# 75%    20609.500000   70000.000000     2.000000     2.000000
# max    29476.000000  170000.000000     5.000000     4.000000
#
#        Commute Distance          Age
# count       6968.000000  6997.000000
# mean           4.210103    45.107332
# std            2.926211    11.916654
# min            1.000000    25.000000
# 25%            1.000000    36.000000
# 50%            4.000000    44.000000
# 75%            6.000000    53.000000
# max           13.000000    96.000000

# %%
bikebuyer["ID"]
# Out:
# 0       22711.0
# 1       13555.0
# 2           NaN
# 3           2.0
# 4       25410.0
# 5           4.0
# 6       15756.0
# 7       11085.0
# 8       17974.0
# 9       21008.0
# 10      28985.0
# 11      11087.0
# 12      20434.0
# 13      14902.0
# 14      11091.0
# 15      11094.0
# 16      18568.0
# 17      16366.0
# 18      20768.0
# 19      11098.0
# 20      18269.0
# 21      11102.0
# 22      11113.0
# 23      26529.0
# 24      11114.0
# 25      23612.0
# 26      11115.0
# 27      11116.0
# 28      11118.0
# 29      19441.0
#          ...
# 6967    22779.0
# 6968    22781.0
# 6969    22783.0
# 6970    22786.0
# 6971    22792.0
# 6972    22793.0
# 6973    22794.0
# 6974    22795.0
# 6975    22796.0
# 6976    22798.0
# 6977    22799.0
# 6978    22801.0
# 6979    22802.0
# 6980    22804.0
# 6981    22805.0
# 6982    22806.0
# 6983    22807.0
# 6984    22809.0
# 6985    22811.0
# 6986    22812.0
# 6987    22813.0
# 6988    22814.0
# 6989    22815.0
# 6990    22818.0
# ...

# %% [markdown]
# # Data Cleaning

# %%
bikebuyer=bikebuyer[bikebuyer["Yearly Income"] != 0]

# %%
bikebuyer.describe()
# Out:
#                  ID  Yearly Income     Children         Cars  \
# count   6994.000000    6995.000000  6978.000000  6995.000000
# mean   17743.970117   57036.454610     1.111780     1.587134
# std     4337.897494   32070.540156     1.600971     1.146768
# min        2.000000   10000.000000     0.000000     0.000000
# 25%    14249.250000   30000.000000     0.000000     1.000000
# 50%    17405.500000   60000.000000     0.000000     2.000000
# 75%    20607.750000   70000.000000     2.000000     2.000000
# max    29476.000000  170000.000000     5.000000     4.000000
#
#        Commute Distance          Age
# count       6966.000000  6995.000000
# mean           4.209589    45.107934
# std            2.925689    11.918004
# min            1.000000    25.000000
# 25%            1.000000    36.000000
# 50%            4.000000    44.000000
# 75%            6.000000    53.000000
# max           13.000000    96.000000

# %%
#Examine GENDER
bikebuyer["Gender"].count()
# Out:
# 6966

# %%
bikebuyer["Gender"].value_counts()
# Out:
# Male      3526
# Female    3440
# Name: Gender, dtype: int64

# %%
#Get a count of missing values in the dataset
bikebuyer.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status      15
# Gender              29
# Yearly Income        0
# Children            17
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
#Examine Marital Status
bikebuyer["Marital Status"].count()
# Out:
# 6980

# %%
bikebuyer["Marital Status"].value_counts()
# Out:
# Married    4133
# Single     2847
# Name: Marital Status, dtype: int64

# %%
bikebuyer['Marital Status'].fillna('Married',inplace=True)
bikebuyer['Marital Status'].value_counts()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# Married    4148
# Single     2847
# Name: Marital Status, dtype: int64

# %%
#After imputatipn Get a count of missing values in the dataset
bikebuyer.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status       0
# Gender              29
# Yearly Income        0
# Children            17
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
bikebuyer['Gender'].fillna('Male',inplace=True)
bikebuyer['Gender'].value_counts()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# Male      3555
# Female    3440
# Name: Gender, dtype: int64

# %%
#After imputatipn Get a count of missing values in the dataset
bikebuyer.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status       0
# Gender               0
# Yearly Income        0
# Children            17
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
bikebuyer["Children"].mean()
# Out:
# 1.111779879621668

# %%
bikebuyer["Children"].median()
# Out:
# 0.0

# %%
bikebuyer["Children"].count()
# Out:
# 6978

# %%
bikebuyer["Children"].value_counts()
# Out:
# 0.0    4041
# 1.0     919
# 2.0     556
# 3.0     531
# 4.0     521
# 5.0     410
# Name: Children, dtype: int64

# %%
bikebuyer['Children'].fillna("0.0",inplace=True)
bikebuyer['Children'].value_counts()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# 0.0    4041
# 1.0     919
# 2.0     556
# 3.0     531
# 4.0     521
# 5.0     410
# 0.0      17
# Name: Children, dtype: int64

# %%
#After imputatipn Get a count of missing values in the dataset
bikebuyer.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status       0
# Gender               0
# Yearly Income        0
# Children             0
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
bikebuyer["Commute Distance"].mean()
# Out:
# 4.209589434395636

# %%
bikebuyer["Commute Distance"].median()
# Out:
# 4.0

# %%
bikebuyer["Commute Distance"].count()
# Out:
# 6966

# %%
bikebuyer["Commute Distance"].value_counts()
# Out:
# 1.0     1750
# 2.0     1149
# 5.0      931
# 7.0      768
# 6.0      632
# 3.0      543
# 8.0      403
# 9.0      282
# 4.0      230
# 11.0     132
# 13.0      74
# 10.0      68
# 12.0       4
# Name: Commute Distance, dtype: int64

# %%
bikebuyer['Commute Distance'].fillna('4.0',inplace=True)
bikebuyer['Commute Distance'].value_counts()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# 1.0     1750
# 2.0     1149
# 5.0      931
# 7.0      768
# 6.0      632
# 3.0      543
# 8.0      403
# 9.0      282
# 4.0      230
# 11.0     132
# 13.0      74
# 10.0      68
# 4.0       29
# 12.0       4
# Name: Commute Distance, dtype: int64

# %%
#After imputatipn Get a count of missing values in the dataset
bikebuyer.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                  1
# Marital Status      0
# Gender              0
# Yearly Income       0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Bike Buyer          0
# dtype: int64

# %%
bikebuyer
# Out:
#            ID Marital Status  Gender  Yearly Income Children  \
# 0     22711.0         Single    Male          30000        0
# 1     13555.0        Married  Female          40000        0
# 2         NaN        Married    Male         160000        5
# 3         2.0         Single    Male         160000        0
# 4     25410.0        Married  Female          70000        2
# 5         4.0        Married    Male         120000        2
# 6     15756.0         Single  Female          70000        0
# 7     11085.0         Single  Female          60000        0
# 9     21008.0         Single  Female          20000        1
# 10    28985.0         Single    Male          50000        0
# 11    11087.0        Married  Female          70000        2
# 12    20434.0         Single    Male          60000        0
# 13    14902.0        Married  Female          40000        0
# 14    11091.0        Married    Male          90000        0
# ...

# %%
#rom os import path
#mport glob
#athfile = os.path.normpath(os.path.join(path,filename))

#ilename = 'bikebuyer4.csv'
#iles_present = glob.glob(filename)
#f not files_present:
#bikebuyer.to_csv(filename)
#lse:
 #print('WARNING: This file already exists!' )
   # overwrite = raw_input("WARNING: " + pathfile + " already exists! Do you want to overwrite <y/n>? \n ")
       #if overwrite == 'y':
       #    bikebuyer.to_csv(pathfile, sep=';'))

# %% [markdown]
# # EDA Univariate

# %%
bikebuyer["Marital Status"].value_counts()
# Out:
# Married    4148
# Single     2847
# Name: Marital Status, dtype: int64

# %%
bikebuyer["Marital Status"].describe()
# Out:
# count        6995
# unique          2
# top       Married
# freq         4148
# Name: Marital Status, dtype: object

# %%
bikebuyer["Marital Status"].hist()

# %%
bikebuyer["Gender"].value_counts()
# Out:
# Male      3555
# Female    3440
# Name: Gender, dtype: int64

# %%
bikebuyer["Gender"].describe()
# Out:
# count     6995
# unique       2
# top       Male
# freq      3555
# Name: Gender, dtype: object

# %%
bikebuyer["Gender"].hist()

# %%
bikebuyer["Yearly Income"].value_counts()
# Out:
# 60000     1291
# 40000      906
# 70000      852
# 30000      834
# 20000      690
# 80000      548
# 10000      509
# 90000      296
# 100000     239
# 50000      226
# 110000     197
# 130000     186
# 120000     127
# 150000      37
# 160000      29
# 170000      28
# Name: Yearly Income, dtype: int64

# %%
bikebuyer["Yearly Income"].describe()
# Out:
# count      6995.000000
# mean      57036.454610
# std       32070.540156
# min       10000.000000
# 25%       30000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      170000.000000
# Name: Yearly Income, dtype: float64

# %%
y_med=bikebuyer["Yearly Income"].median()
y_med
# Out:
# 60000.0

# %%
np.var(bikebuyer["Yearly Income"])
# Out:
# 1028372509.517453

# %%
#Plotting Histogram and Boxplot for Visualization
bikebuyer["Yearly Income"].hist()

# %%
bikebuyer.boxplot(column='Yearly Income')

# %%
bikebuyer[['Children','Commute Distance']] = bikebuyer[['Children','Commute Distance']].apply(pd.to_numeric)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
bikebuyer["Children"].value_counts()
# Out:
# 0.0    4058
# 1.0     919
# 2.0     556
# 3.0     531
# 4.0     521
# 5.0     410
# Name: Children, dtype: int64

# %%
bikebuyer["Children"].describe()
# Out:
# count    6995.000000
# mean        1.109078
# std         1.599961
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max         5.000000
# Name: Children, dtype: float64

# %%
bikebuyer["Children"].median()
# Out:
# 0.0

# %%
#np.var(bikebuyer["Children"])

# %%
#Plotting Histogram and Boxplot for Visualization of Children
bikebuyer["Children"].hist()

# %%
bikebuyer.boxplot(column='Children')

# %%
bikebuyer["Education"].value_counts()
# Out:
# Partial College        1931
# Bachelors              1869
# High School            1313
# Graduate Degree        1272
# Partial High School     610
# Name: Education, dtype: int64

# %%
bikebuyer["Education"].describe()
# Out:
# count                6995
# unique                  5
# top       Partial College
# freq                 1931
# Name: Education, dtype: object

# %%
bikebuyer["Education"].hist()

# %%
bikebuyer["Occupation"].value_counts()
# Out:
# Professional      2031
# Skilled Manual    1748
# Management        1265
# Manual             990
# Clerical           961
# Name: Occupation, dtype: int64

# %%
bikebuyer["Occupation"].describe()
# Out:
# count             6995
# unique               5
# top       Professional
# freq              2031
# Name: Occupation, dtype: object

# %%
bikebuyer["Occupation"].hist()

# %%
bikebuyer["Home Owner"].value_counts()
# Out:
# Yes    4977
# No     2018
# Name: Home Owner, dtype: int64

# %%
bikebuyer["Home Owner"].describe()
# Out:
# count     6995
# unique       2
# top        Yes
# freq      4977
# Name: Home Owner, dtype: object

# %%
bikebuyer["Home Owner"].hist()

# %%
bikebuyer["Cars"].value_counts()
# Out:
# 2    2581
# 1    1787
# 0    1430
# 3     635
# 4     562
# Name: Cars, dtype: int64

# %%
bikebuyer["Cars"].describe()
# Out:
# count    6995.000000
# mean        1.587134
# std         1.146768
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: Cars, dtype: float64

# %%
bikebuyer["Cars"].median()
# Out:
# 2.0

# %%
np.var(bikebuyer["Cars"])
# Out:
# 1.3148880671939502

# %%
bikebuyer["Cars"].hist()

# %%
bikebuyer.boxplot(column="Cars")

# %%
bikebuyer["Commute Distance"].value_counts()
# Out:
# 1.0     1750
# 2.0     1149
# 5.0      931
# 7.0      768
# 6.0      632
# 3.0      543
# 8.0      403
# 9.0      282
# 4.0      259
# 11.0     132
# 13.0      74
# 10.0      68
# 12.0       4
# Name: Commute Distance, dtype: int64

# %%
bikebuyer["Commute Distance"].describe()
# Out:
# count    6995.000000
# mean        4.208721
# std         2.919648
# min         1.000000
# 25%         1.000000
# 50%         4.000000
# 75%         6.000000
# max        13.000000
# Name: Commute Distance, dtype: float64

# %%
bikebuyer["Commute Distance"].hist()

# %%
bikebuyer["Region"].value_counts()
# Out:
# North America    3727
# Europe           2095
# Pacific          1173
# Name: Region, dtype: int64

# %%
bikebuyer["Region"].describe()
# Out:
# count              6995
# unique                3
# top       North America
# freq               3727
# Name: Region, dtype: object

# %%
bikebuyer["Region"].hist()

# %%
bikebuyer["Age"].value_counts()
# Out:
# 42    283
# 41    251
# 35    232
# 39    229
# 48    224
# 44    219
# 43    217
# 45    216
# 40    215
# 30    207
# 46    206
# 33    195
# 38    191
# 37    189
# 47    189
# 31    188
# 34    186
# 32    173
# 36    170
# 49    162
# 29    160
# 28    154
# 50    150
# 53    145
# 52    143
# 55    141
# 51    135
# 56    132
# 58    132
# 27    131
#      ...
# 64     87
# 65     61
# 68     56
# 69     55
# 66     52
# 67     41
# 70     36
# 71     35
# 72     31
# 73     24
# 25     13
# 74     10
# 75      8
# 77      8
# 76      6
# 78      5
# 80      5
# 84      4
# 94      3
# 86      3
# 82      3
# 79      2
# 83      2
# 93      2
# 89      2
# 85      1
# 96      1
# 90      1
# 87      1
# 95      1
# Name: Age, Length: 68, dtype: int64

# %%
bikebuyer["Age"].describe()
# Out:
# count    6995.000000
# mean       45.107934
# std        11.918004
# min        25.000000
# 25%        36.000000
# 50%        44.000000
# 75%        53.000000
# max        96.000000
# Name: Age, dtype: float64

# %%
bikebuyer["Age"].median()
# Out:
# 44.0

# %%
np.var(bikebuyer["Age"])
# Out:
# 142.018514603251

# %%
bikebuyer["Age"].hist()

# %%
from scipy.stats import norm
x_axis = np.arange(0, 100,20)
#Mean = 45.107934 , Std=11.918004
plt.plot(x_axis, norm.pdf(x_axis,45.107934,11.918004))
plt.xlabel("Age")
plt.ylabel("Population")
plt.show()

# %%
bikebuyer.boxplot(column="Age")

# %%
bikebuyer["Bike Buyer"].value_counts()
# Out:
# No     5997
# Yes     998
# Name: Bike Buyer, dtype: int64

# %%
bikebuyer["Bike Buyer"].describe()
# Out:
# count     6995
# unique       2
# top         No
# freq      5997
# Name: Bike Buyer, dtype: object

# %%
bikebuyer["Bike Buyer"].hist()

# %%
bikebuyer.dtypes
# Out:
# ID                  float64
# Marital Status       object
# Gender               object
# Yearly Income         int64
# Children            float64
# Education            object
# Occupation           object
# Home Owner           object
# Cars                  int64
# Commute Distance    float64
# Region               object
# Age                   int64
# Bike Buyer           object
# dtype: object

# %%
#EDA Multivariate

# %%
bikebuyer.describe(include='all')
# Out:
#                   ID Marital Status Gender  Yearly Income     Children  \
# count    6994.000000           6995   6995    6995.000000  6995.000000
# unique           NaN              2      2            NaN          NaN
# top              NaN        Married   Male            NaN          NaN
# freq             NaN           4148   3555            NaN          NaN
# mean    17743.970117            NaN    NaN   57036.454610     1.109078
# std      4337.897494            NaN    NaN   32070.540156     1.599961
# min         2.000000            NaN    NaN   10000.000000     0.000000
# 25%     14249.250000            NaN    NaN   30000.000000     0.000000
# 50%     17405.500000            NaN    NaN   60000.000000     0.000000
# 75%     20607.750000            NaN    NaN   70000.000000     2.000000
# max     29476.000000            NaN    NaN  170000.000000     5.000000
#
#               Education    Occupation Home Owner         Cars  \
# ...

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  255
# Marital Status      255
# Gender              255
# Yearly Income       255
# Children            255
# Education           255
# Occupation          255
# Home Owner          255
# Cars                255
# Commute Distance    255
# Region              255
# Age                 255
# Bike Buyer          255
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  1686
# Marital Status      1686
# Gender              1686
# Yearly Income       1686
# Children            1686
# Education           1686
# Occupation          1686
# Home Owner          1686
# Cars                1686
# Commute Distance    1686
# Region              1686
# Age                 1686
# Bike Buyer          1686
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  222
# Marital Status      222
# Gender              222
# Yearly Income       222
# Children            222
# Education           222
# Occupation          222
# Home Owner          222
# Cars                222
# Commute Distance    222
# Region              222
# Age                 222
# Bike Buyer          222
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  1233
# Marital Status      1233
# Gender              1233
# Yearly Income       1233
# Children            1233
# Education           1233
# Occupation          1233
# Home Owner          1233
# Cars                1233
# Commute Distance    1233
# Region              1233
# Age                 1233
# Bike Buyer          1233
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Region'].str.contains('Europe')&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  134
# Marital Status      134
# Gender              134
# Yearly Income       134
# Children            134
# Education           134
# Occupation          134
# Home Owner          134
# Cars                134
# Commute Distance    134
# Region              134
# Age                 134
# Bike Buyer          134
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Region'].str.contains('Europe')&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  900
# Marital Status      901
# Gender              901
# Yearly Income       901
# Children            901
# Education           901
# Occupation          901
# Home Owner          901
# Cars                901
# Commute Distance    901
# Region              901
# Age                 901
# Bike Buyer          901
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Region'].str.contains('Europe')&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  146
# Marital Status      146
# Gender              146
# Yearly Income       146
# Children            146
# Education           146
# Occupation          146
# Home Owner          146
# Cars                146
# Commute Distance    146
# Region              146
# Age                 146
# Bike Buyer          146
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Region'].str.contains('Europe')&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  914
# Marital Status      914
# Gender              914
# Yearly Income       914
# Children            914
# Education           914
# Occupation          914
# Home Owner          914
# Cars                914
# Commute Distance    914
# Region              914
# Age                 914
# Bike Buyer          914
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Region'].str.contains('North America')&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  226
# Marital Status      226
# Gender              226
# Yearly Income       226
# Children            226
# Education           226
# Occupation          226
# Home Owner          226
# Cars                226
# Commute Distance    226
# Region              226
# Age                 226
# Bike Buyer          226
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Region'].str.contains('North America')&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  1693
# Marital Status      1693
# Gender              1693
# Yearly Income       1693
# Children            1693
# Education           1693
# Occupation          1693
# Home Owner          1693
# Cars                1693
# Commute Distance    1693
# Region              1693
# Age                 1693
# Bike Buyer          1693
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Region'].str.contains('North America')&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  254
# Marital Status      254
# Gender              254
# Yearly Income       254
# Children            254
# Education           254
# Occupation          254
# Home Owner          254
# Cars                254
# Commute Distance    254
# Region              254
# Age                 254
# Bike Buyer          254
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Region'].str.contains('North America')&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  1554
# Marital Status      1554
# Gender              1554
# Yearly Income       1554
# Children            1554
# Education           1554
# Occupation          1554
# Home Owner          1554
# Cars                1554
# Commute Distance    1554
# Region              1554
# Age                 1554
# Bike Buyer          1554
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Region'].str.contains('Pacific')&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  117
# Marital Status      117
# Gender              117
# Yearly Income       117
# Children            117
# Education           117
# Occupation          117
# Home Owner          117
# Cars                117
# Commute Distance    117
# Region              117
# Age                 117
# Bike Buyer          117
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Region'].str.contains('Pacific')&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  484
# Marital Status      484
# Gender              484
# Yearly Income       484
# Children            484
# Education           484
# Occupation          484
# Home Owner          484
# Cars                484
# Commute Distance    484
# Region              484
# Age                 484
# Bike Buyer          484
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Region'].str.contains('Pacific')&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  121
# Marital Status      121
# Gender              121
# Yearly Income       121
# Children            121
# Education           121
# Occupation          121
# Home Owner          121
# Cars                121
# Commute Distance    121
# Region              121
# Age                 121
# Bike Buyer          121
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Region'].str.contains('Pacific')&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  451
# Marital Status      451
# Gender              451
# Yearly Income       451
# Children            451
# Education           451
# Occupation          451
# Home Owner          451
# Cars                451
# Commute Distance    451
# Region              451
# Age                 451
# Bike Buyer          451
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([0.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  157
# Marital Status      157
# Gender              157
# Yearly Income       157
# Children            157
# Education           157
# Occupation          157
# Home Owner          157
# Cars                157
# Commute Distance    157
# Region              157
# Age                 157
# Bike Buyer          157
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([0.0])&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  1051
# Marital Status      1051
# Gender              1051
# Yearly Income       1051
# Children            1051
# Education           1051
# Occupation          1051
# Home Owner          1051
# Cars                1051
# Commute Distance    1051
# Region              1051
# Age                 1051
# Bike Buyer          1051
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([1.0])&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  312
# Marital Status      312
# Gender              312
# Yearly Income       312
# Children            312
# Education           312
# Occupation          312
# Home Owner          312
# Cars                312
# Commute Distance    312
# Region              312
# Age                 312
# Bike Buyer          312
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([0.0])&bikebuyer['Bike Buyer'].str.contains('No')].count()
# Out:
# ID                  1051
# Marital Status      1051
# Gender              1051
# Yearly Income       1051
# Children            1051
# Education           1051
# Occupation          1051
# Home Owner          1051
# Cars                1051
# Commute Distance    1051
# Region              1051
# Age                 1051
# Bike Buyer          1051
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([1.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  44
# Marital Status      44
# Gender              44
# Yearly Income       44
# Children            44
# Education           44
# Occupation          44
# Home Owner          44
# Cars                44
# Commute Distance    44
# Region              44
# Age                 44
# Bike Buyer          44
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([2.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  20
# Marital Status      20
# Gender              20
# Yearly Income       20
# Children            20
# Education           20
# Occupation          20
# Home Owner          20
# Cars                20
# Commute Distance    20
# Region              20
# Age                 20
# Bike Buyer          20
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([3.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  6
# Marital Status      6
# Gender              6
# Yearly Income       6
# Children            6
# Education           6
# Occupation          6
# Home Owner          6
# Cars                6
# Commute Distance    6
# Region              6
# Age                 6
# Bike Buyer          6
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([4.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  10
# Marital Status      10
# Gender              10
# Yearly Income       10
# Children            10
# Education           10
# Occupation          10
# Home Owner          10
# Cars                10
# Commute Distance    10
# Region              10
# Age                 10
# Bike Buyer          10
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([5.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  18
# Marital Status      18
# Gender              18
# Yearly Income       18
# Children            18
# Education           18
# Occupation          18
# Home Owner          18
# Cars                18
# Commute Distance    18
# Region              18
# Age                 18
# Bike Buyer          18
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([0.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  138
# Marital Status      138
# Gender              138
# Yearly Income       138
# Children            138
# Education           138
# Occupation          138
# Home Owner          138
# Cars                138
# Commute Distance    138
# Region              138
# Age                 138
# Bike Buyer          138
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([1.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  19
# Marital Status      19
# Gender              19
# Yearly Income       19
# Children            19
# Education           19
# Occupation          19
# Home Owner          19
# Cars                19
# Commute Distance    19
# Region              19
# Age                 19
# Bike Buyer          19
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([2.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  34
# Marital Status      34
# Gender              34
# Yearly Income       34
# Children            34
# Education           34
# Occupation          34
# Home Owner          34
# Cars                34
# Commute Distance    34
# Region              34
# Age                 34
# Bike Buyer          34
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([3.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  15
# Marital Status      15
# Gender              15
# Yearly Income       15
# Children            15
# Education           15
# Occupation          15
# Home Owner          15
# Cars                15
# Commute Distance    15
# Region              15
# Age                 15
# Bike Buyer          15
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([4.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  8
# Marital Status      8
# Gender              8
# Yearly Income       8
# Children            8
# Education           8
# Occupation          8
# Home Owner          8
# Cars                8
# Commute Distance    8
# Region              8
# Age                 8
# Bike Buyer          8
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Male')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([5.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  8
# Marital Status      8
# Gender              8
# Yearly Income       8
# Children            8
# Education           8
# Occupation          8
# Home Owner          8
# Cars                8
# Commute Distance    8
# Region              8
# Age                 8
# Bike Buyer          8
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([0.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  167
# Marital Status      167
# Gender              167
# Yearly Income       167
# Children            167
# Education           167
# Occupation          167
# Home Owner          167
# Cars                167
# Commute Distance    167
# Region              167
# Age                 167
# Bike Buyer          167
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([1.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  37
# Marital Status      37
# Gender              37
# Yearly Income       37
# Children            37
# Education           37
# Occupation          37
# Home Owner          37
# Cars                37
# Commute Distance    37
# Region              37
# Age                 37
# Bike Buyer          37
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([2.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  17
# Marital Status      17
# Gender              17
# Yearly Income       17
# Children            17
# Education           17
# Occupation          17
# Home Owner          17
# Cars                17
# Commute Distance    17
# Region              17
# Age                 17
# Bike Buyer          17
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([3.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  5
# Marital Status      5
# Gender              5
# Yearly Income       5
# Children            5
# Education           5
# Occupation          5
# Home Owner          5
# Cars                5
# Commute Distance    5
# Region              5
# Age                 5
# Bike Buyer          5
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([4.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  8
# Marital Status      8
# Gender              8
# Yearly Income       8
# Children            8
# Education           8
# Occupation          8
# Home Owner          8
# Cars                8
# Commute Distance    8
# Region              8
# Age                 8
# Bike Buyer          8
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Married')&bikebuyer['Children'].isin([5.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  15
# Marital Status      15
# Gender              15
# Yearly Income       15
# Children            15
# Education           15
# Occupation          15
# Home Owner          15
# Cars                15
# Commute Distance    15
# Region              15
# Age                 15
# Bike Buyer          15
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([0.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  169
# Marital Status      169
# Gender              169
# Yearly Income       169
# Children            169
# Education           169
# Occupation          169
# Home Owner          169
# Cars                169
# Commute Distance    169
# Region              169
# Age                 169
# Bike Buyer          169
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([1.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  21
# Marital Status      21
# Gender              21
# Yearly Income       21
# Children            21
# Education           21
# Occupation          21
# Home Owner          21
# Cars                21
# Commute Distance    21
# Region              21
# Age                 21
# Bike Buyer          21
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([2.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  31
# Marital Status      31
# Gender              31
# Yearly Income       31
# Children            31
# Education           31
# Occupation          31
# Home Owner          31
# Cars                31
# Commute Distance    31
# Region              31
# Age                 31
# Bike Buyer          31
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([3.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  25
# Marital Status      25
# Gender              25
# Yearly Income       25
# Children            25
# Education           25
# Occupation          25
# Home Owner          25
# Cars                25
# Commute Distance    25
# Region              25
# Age                 25
# Bike Buyer          25
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([4.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  16
# Marital Status      16
# Gender              16
# Yearly Income       16
# Children            16
# Education           16
# Occupation          16
# Home Owner          16
# Cars                16
# Commute Distance    16
# Region              16
# Age                 16
# Bike Buyer          16
# dtype: int64

# %%
bikebuyer[bikebuyer['Gender'].str.contains('Female')&bikebuyer['Marital Status'].str.contains('Single')&bikebuyer['Children'].isin([5.0])&bikebuyer['Bike Buyer'].str.contains('Yes')].count()
# Out:
# ID                  10
# Marital Status      10
# Gender              10
# Yearly Income       10
# Children            10
# Education           10
# Occupation          10
# Home Owner          10
# Cars                10
# Commute Distance    10
# Region              10
# Age                 10
# Bike Buyer          10
# dtype: int64

# %%
gen=bikebuyer["Gender"]
year=bikebuyer["Yearly Income"]
mar=bikebuyer["Marital Status"]
chd=bikebuyer["Children"]
bb=bikebuyer["Bike Buyer"]
age=bikebuyer["Age"]
ed=bikebuyer["Education"]
com=bikebuyer["Commute Distance"]
hom=bikebuyer["Home Owner"]
car=bikebuyer["Cars"]

# %%
plt.scatter( chd , year, marker='x')
plt.show()

# %%
plt.scatter( chd , age, marker='x')
plt.show()

# %%
plt.scatter( chd , ed, marker='x')
plt.show()

# %%
plt.scatter( car , bb, marker='x')
plt.show()

# %%
plt.scatter(ed,age, marker='o')
plt.show()

# %%
bikebuyer=bikebuyer.replace(['Married','Single'],['1','0'])
bikebuyer=bikebuyer.replace(['Male','Female'],['1','0'])
bikebuyer=bikebuyer.replace(['Yes','No'],['1','0'])

bikebuyer[['Marital Status']] = bikebuyer[['Marital Status']].apply(pd.to_numeric)
bikebuyer[['Gender']] = bikebuyer[['Gender']].apply(pd.to_numeric)
bikebuyer[['Bike Buyer']] = bikebuyer[['Bike Buyer']].apply(pd.to_numeric)

# %%
gen=bikebuyer["Gender"]
year=bikebuyer["Yearly Income"]
mar=bikebuyer["Marital Status"]
chd=bikebuyer["Children"]
bb=bikebuyer["Bike Buyer"]
age=bikebuyer["Age"]
ed=bikebuyer["Education"]
com=bikebuyer["Commute Distance"]
hom=bikebuyer["Home Owner"]
car=bikebuyer["Cars"]

# %%
bikebuyer.boxplot(column="Yearly Income" , by ="Marital Status")

# %%
plt.hist2d(mar,year)
plt.colorbar()
plt.xlabel("Marital Status Yes=1 and No=0")
plt.ylabel("Income")
plt.show()

# %%
bikebuyer.boxplot(column="Yearly Income" , by ="Gender")

# %%
plt.hist2d(gen,year)
plt.colorbar()
plt.xlabel("Gender Male=1 and Female=0")
plt.ylabel("Income")
plt.show()

# %%
bikebuyer.boxplot(column="Yearly Income" , by ="Children")

# %%
bikebuyer.boxplot(column="Yearly Income" , by ="Education")

# %%
bikebuyer.boxplot(column="Yearly Income" , by ="Occupation")

# %%
bikebuyer.boxplot(column="Yearly Income" , by ="Home Owner")

# %%
bikebuyer.boxplot(column="Yearly Income" , by ="Cars")

# %%
plt.hist2d(car,year)
plt.colorbar()
plt.show()

# %%
bikebuyer.boxplot(column="Yearly Income" , by ="Bike Buyer")

# %%
bikebuyer.boxplot(column="Children" , by ="Bike Buyer")

# %%
bikebuyer.boxplot(column="Age" , by ="Education")

# %%
bikebuyer.boxplot(column="Age" , by ="Marital Status")

# %%
bikebuyer.boxplot(column="Age" , by ="Gender")

# %%
plt.hist2d(age,year)
plt.colorbar()
plt.show()

# %%
bikebuyer.boxplot(column="Age" , by ="Occupation")

# %%
bikebuyer.boxplot(column="Age" , by ="Bike Buyer")

# %%
bikebuyer.boxplot(column="Cars" , by ="Bike Buyer")

# %%
pd.crosstab(bikebuyer['Gender'],bikebuyer['Bike Buyer'],margins=True)
# Out:
# Bike Buyer     0    1   All
# Gender
# 0           2919  521  3440
# 1           3078  477  3555
# All         5997  998  6995

# %%
plt.hist2d(bb,gen)
plt.colorbar()
plt.xlabel("Bike Buyer Yes=1 and No=0")
plt.ylabel("Gender")
plt.show()

# %%
bikebuyer.hist(column='Gender',by='Bike Buyer',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C0BC4D6D8>,
# ...
#       dtype=object)

# %%
pd.crosstab(bikebuyer['Marital Status'],bikebuyer['Bike Buyer'],margins=True)
# Out:
# Bike Buyer         0    1   All
# Marital Status
# 0               2353  494  2847
# 1               3644  504  4148
# All             5997  998  6995

# %%
plt.hist2d(bb,mar)
plt.colorbar()
plt.xlabel("Bike Buyer Yes=1 and No=0")
plt.ylabel("Marital Status Married=1 and Single=0")
plt.show()

# %%
pd.crosstab(bikebuyer['Yearly Income'],bikebuyer['Bike Buyer'],margins=True)
# Out:
# Bike Buyer        0    1   All
# Yearly Income
# 10000           462   47   509
# 20000           608   82   690
# 30000           725  109   834
# 40000           748  158   906
# 50000           182   44   226
# 60000          1111  180  1291
# 70000           705  147   852
# 80000           480   68   548
# 90000           245   51   296
# 100000          217   22   239
# 110000          169   28   197
# 120000          107   20   127
# 130000          156   30   186
# 150000           30    7    37
# 160000           26    3    29
# 170000           26    2    28
# All            5997  998  6995

# %%
bikebuyer.hist(column='Yearly Income',by='Bike Buyer',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C0B6CBD30>,
# ...
#       dtype=object)

# %%
plt.hist2d(bb,year)
plt.colorbar()
plt.xlabel("Bike Buyer Yes=1 and No=0")
plt.ylabel("Income")
plt.show()

# %%
pd.crosstab(bikebuyer['Children'],bikebuyer['Bike Buyer'],margins=True)
# Out:
# Bike Buyer     0    1   All
# Children
# 0.0         3427  631  4058
# 1.0          798  121   919
# 2.0          454  102   556
# 3.0          480   51   531
# 4.0          479   42   521
# 5.0          359   51   410
# All         5997  998  6995

# %%
bikebuyer.hist(column='Children',by='Bike Buyer',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C0A0B42B0>,
# ...
#       dtype=object)

# %%
plt.hist2d(bb,chd)
plt.colorbar()
plt.xlabel("Bike Buyer Yes=1 and No=0")
plt.ylabel("Children")
plt.show()

# %%
pd.crosstab(bikebuyer['Occupation'],bikebuyer['Bike Buyer'],margins=True)
# Out:
# Bike Buyer         0    1   All
# Occupation
# Clerical         784  177   961
# Management      1112  153  1265
# Manual           887  103   990
# Professional    1719  312  2031
# Skilled Manual  1495  253  1748
# All             5997  998  6995

# %%
bikebuyer.hist(column='Occupation',by='Bike Buyer',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C0A2E4128>,
# ...
#       dtype=object)

# %%
pd.crosstab(bikebuyer['Cars'],bikebuyer['Bike Buyer'],margins=True)
# Out:
# Bike Buyer     0    1   All
# Cars
# 0           1132  298  1430
# 1           1505  282  1787
# 2           2304  277  2581
# 3            552   83   635
# 4            504   58   562
# All         5997  998  6995

# %%
bikebuyer.hist(column='Cars',by='Bike Buyer',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C0BCEBDA0>,
# ...
#       dtype=object)

# %%
plt.hist2d(bb,car)
plt.colorbar()
plt.xlabel("Bike Buyer Yes=1 and No=0")
plt.ylabel("Cars")
plt.show()

# %%
#describing the relationships among the features
bikebuyer.describe()
# Out:
#                  ID  Marital Status       Gender  Yearly Income     Children  \
# count   6994.000000     6995.000000  6995.000000    6995.000000  6995.000000
# mean   17743.970117        0.592995     0.508220   57036.454610     1.109078
# std     4337.897494        0.491311     0.499968   32070.540156     1.599961
# min        2.000000        0.000000     0.000000   10000.000000     0.000000
# 25%    14249.250000        0.000000     0.000000   30000.000000     0.000000
# 50%    17405.500000        1.000000     1.000000   60000.000000     0.000000
# 75%    20607.750000        1.000000     1.000000   70000.000000     2.000000
# max    29476.000000        1.000000     1.000000  170000.000000     5.000000
#
#               Cars  Commute Distance          Age   Bike Buyer
# count  6995.000000       6995.000000  6995.000000  6995.000000
# mean      1.587134          4.208721    45.107934     0.142673
# std       1.146768          2.919648    11.918004     0.349764
# ...

# %%
bikebuyer.hist(column='Commute Distance',by='Bike Buyer',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C0BE2D780>,
# ...
#       dtype=object)

# %%
plt.hist2d(bb,com)
plt.colorbar()
plt.xlabel("Bike Buyer Yes=1 and No=0")
plt.ylabel("Commute Distance")
plt.show()

# %%
bikebuyer.hist(column='Home Owner',by='Bike Buyer',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C0BF2F780>,
# ...
#       dtype=object)

# %%
pd.crosstab(bikebuyer['Age'],bikebuyer['Bike Buyer'],margins=True)
# Out:
# Bike Buyer     0    1   All
# Age
# 25            12    1    13
# 26            86   12    98
# 27           113   18   131
# 28           129   25   154
# 29           153    7   160
# 30           194   13   207
# 31           163   25   188
# 32           157   16   173
# 33           167   28   195
# 34           155   31   186
# 35           198   34   232
# 36           122   48   170
# 37           124   65   189
# 38           143   48   191
# 39           190   39   229
# 40           177   38   215
# 41           225   26   251
# 42           253   30   283
# 43           179   38   217
# 44           188   31   219
# 45           177   39   216
# 46           173   33   206
# 47           158   31   189
# 48           187   37   224
# 49           135   27   162
# 50           129   21   150
# 51           104   31   135
# 52           118   25   143
# 53           129   16   145
# 54            97   25   122
# ..           ...  ...   ...
# 64            86    1    87
# ...

# %%
bikebuyer.hist(column='Age',by='Bike Buyer',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C0C006CF8>,
# ...
#       dtype=object)

# %%
plt.hist2d(bb,age)
plt.colorbar()
plt.xlabel("Bike Buyer Yes=1 and No=0")
plt.ylabel("Age")
plt.show()

# %%
#x1=pd.DataFrame[bikebuyer]

# %%
x=bikebuyer.iloc[:,1:12]
y=bikebuyer.iloc[:,-1]

# %%
x.head()
# Out:
#    Marital Status  Gender  Yearly Income  Children        Education  \
# 0               0       1          30000       0.0  Partial College
# 1               1       0          40000       0.0  Graduate Degree
# 2               1       1         160000       5.0  Partial College
# 3               0       1         160000       0.0  Graduate Degree
# 4               1       0          70000       2.0        Bachelors
#
#        Occupation Home Owner  Cars  Commute Distance         Region  Age
# 0        Clerical          0     1               1.0         Europe   33
# 1        Clerical          1     0               1.0         Europe   37
# 2    Professional          0     3               2.0         Europe   55
# 3      Management          1     2               5.0        Pacific   47
# 4  Skilled Manual          0     1               1.0  North America   38

# %%
x['Education'].value_counts()
# Out:
# Partial College        1931
# Bachelors              1869
# High School            1313
# Graduate Degree        1272
# Partial High School     610
# Name: Education, dtype: int64

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Bike Buyer, dtype: int64

# %%
#Encode the independent variable 'Marital Status'
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x=LabelEncoder()
x.iloc[:,0]=labelencoder_x.fit_transform(x.iloc[:,0])
x
# Out:
#       Marital Status  Gender  Yearly Income  Children            Education  \
# 0                  0       1          30000       0.0      Partial College
# 1                  1       0          40000       0.0      Graduate Degree
# 2                  1       1         160000       5.0      Partial College
# 3                  0       1         160000       0.0      Graduate Degree
# 4                  1       0          70000       2.0            Bachelors
# 5                  1       1         120000       2.0            Bachelors
# 6                  0       0          70000       0.0          High School
# 7                  0       0          60000       0.0          High School
# 9                  0       0          20000       1.0      Partial College
# 10                 0       1          50000       0.0            Bachelors
# 11                 1       0          70000       2.0      Partial College
# ...

# %%
#Encode the independent variable 'Gender'
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x=LabelEncoder()
x.iloc[:,1]=labelencoder_x.fit_transform(x.iloc[:,1])
x
# Out:
#       Marital Status  Gender  Yearly Income  Children            Education  \
# 0                  0       1          30000       0.0      Partial College
# 1                  1       0          40000       0.0      Graduate Degree
# 2                  1       1         160000       5.0      Partial College
# 3                  0       1         160000       0.0      Graduate Degree
# 4                  1       0          70000       2.0            Bachelors
# 5                  1       1         120000       2.0            Bachelors
# 6                  0       0          70000       0.0          High School
# 7                  0       0          60000       0.0          High School
# 9                  0       0          20000       1.0      Partial College
# 10                 0       1          50000       0.0            Bachelors
# 11                 1       0          70000       2.0      Partial College
# ...

# %%
#Encode the independent variable 'Education'
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x=LabelEncoder()
x.iloc[:,4]=labelencoder_x.fit_transform(x.iloc[:,4])
x
# Out:
#       Marital Status  Gender  Yearly Income  Children  Education  \
# 0                  0       1          30000       0.0          3
# 1                  1       0          40000       0.0          1
# 2                  1       1         160000       5.0          3
# 3                  0       1         160000       0.0          1
# 4                  1       0          70000       2.0          0
# 5                  1       1         120000       2.0          0
# 6                  0       0          70000       0.0          2
# 7                  0       0          60000       0.0          2
# 9                  0       0          20000       1.0          3
# 10                 0       1          50000       0.0          0
# 11                 1       0          70000       2.0          3
# 12                 0       1          60000       0.0          3
# 13                 1       0          40000       0.0          3
# ...

# %%
#Encode the independent variable 'Occupation'
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x=LabelEncoder()
x.iloc[:,5]=labelencoder_x.fit_transform(x.iloc[:,5])
x
# Out:
#       Marital Status  Gender  Yearly Income  Children  Education  Occupation  \
# 0                  0       1          30000       0.0          3           0
# 1                  1       0          40000       0.0          1           0
# 2                  1       1         160000       5.0          3           3
# 3                  0       1         160000       0.0          1           1
# 4                  1       0          70000       2.0          0           4
# 5                  1       1         120000       2.0          0           1
# 6                  0       0          70000       0.0          2           3
# 7                  0       0          60000       0.0          2           3
# 9                  0       0          20000       1.0          3           2
# 10                 0       1          50000       0.0          0           1
# 11                 1       0          70000       2.0          3           3
# ...

# %%
#Encode the independent variable 'Home Owner'
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x=LabelEncoder()
x.iloc[:,6]=labelencoder_x.fit_transform(x.iloc[:,6])
x
# Out:
#       Marital Status  Gender  Yearly Income  Children  Education  Occupation  \
# 0                  0       1          30000       0.0          3           0
# 1                  1       0          40000       0.0          1           0
# 2                  1       1         160000       5.0          3           3
# 3                  0       1         160000       0.0          1           1
# 4                  1       0          70000       2.0          0           4
# 5                  1       1         120000       2.0          0           1
# 6                  0       0          70000       0.0          2           3
# 7                  0       0          60000       0.0          2           3
# 9                  0       0          20000       1.0          3           2
# 10                 0       1          50000       0.0          0           1
# 11                 1       0          70000       2.0          3           3
# ...

# %%
#Encode the independent variable 'Region'
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x=LabelEncoder()
x.iloc[:,9]=labelencoder_x.fit_transform(x.iloc[:,9])
x
# Out:
#       Marital Status  Gender  Yearly Income  Children  Education  Occupation  \
# 0                  0       1          30000       0.0          3           0
# 1                  1       0          40000       0.0          1           0
# 2                  1       1         160000       5.0          3           3
# 3                  0       1         160000       0.0          1           1
# 4                  1       0          70000       2.0          0           4
# 5                  1       1         120000       2.0          0           1
# 6                  0       0          70000       0.0          2           3
# 7                  0       0          60000       0.0          2           3
# 9                  0       0          20000       1.0          3           2
# 10                 0       1          50000       0.0          0           1
# 11                 1       0          70000       2.0          3           3
# ...

# %%
#One Hot Encoder to 'Education'
onehotencoder = OneHotEncoder(categorical_features =[4])
x=onehotencoder.fit_transform(x).toarray()
x
# Out:
# array([[ 0.,  0.,  0., ...,  1.,  0., 33.],
#        [ 0.,  1.,  0., ...,  1.,  0., 37.],
#        [ 0.,  0.,  0., ...,  2.,  0., 55.],
#        ...,
#        [ 1.,  0.,  0., ...,  1.,  0., 53.],
#        [ 0.,  0.,  0., ...,  1.,  0., 54.],
#        [ 0.,  0.,  1., ...,  2.,  0., 54.]])

# %%
#One Hot Encoder to 'Occupation'
onehotencoder = OneHotEncoder(categorical_features =[5])
x=onehotencoder.fit_transform(x).toarray()
x
# Out:
# array([[ 1.,  0.,  0., ...,  1.,  0., 33.],
#        [ 0.,  1.,  0., ...,  1.,  0., 37.],
#        [ 0.,  1.,  0., ...,  2.,  0., 55.],
#        ...,
#        [ 0.,  1.,  1., ...,  1.,  0., 53.],
#        [ 1.,  0.,  0., ...,  1.,  0., 54.],
#        [ 0.,  1.,  0., ...,  2.,  0., 54.]])

# %%
#One Hot Encoder to 'Region'
onehotencoder = OneHotEncoder(categorical_features =[9])
x=onehotencoder.fit_transform(x).toarray()
x
# Out:
# array([[ 1.,  0.,  0., ...,  1.,  0., 33.],
#        [ 1.,  0.,  0., ...,  1.,  0., 37.],
#        [ 0.,  0.,  0., ...,  2.,  0., 55.],
#        ...,
#        [ 0.,  0.,  0., ...,  1.,  0., 53.],
#        [ 0.,  0.,  0., ...,  1.,  0., 54.],
#        [ 0.,  0.,  0., ...,  2.,  0., 54.]])

# %%
x
# Out:
# array([[ 1.,  0.,  0., ...,  1.,  0., 33.],
#        [ 1.,  0.,  0., ...,  1.,  0., 37.],
#        [ 0.,  0.,  0., ...,  2.,  0., 55.],
#        ...,
#        [ 0.,  0.,  0., ...,  1.,  0., 53.],
#        [ 0.,  0.,  0., ...,  1.,  0., 54.],
#        [ 0.,  0.,  0., ...,  2.,  0., 54.]])

# %% [markdown]
# # kNearest Neighbor

# %%
#Splitting the data set into Training set and test set
from sklearn import cross_validation,neighbors
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
# array([[ 0.,  0.,  0., ...,  5.,  0., 60.],
#        [ 1.,  0.,  0., ..., 13.,  0., 40.],
#        [ 1.,  0.,  0., ...,  6.,  0., 63.],
#        ...,
#        [ 1.,  0.,  0., ..., 11.,  1., 28.],
#        [ 0.,  0.,  1., ...,  5.,  1., 54.],
#        [ 1.,  0.,  0., ...,  1.,  0., 37.]])

# %%
x_train.shape
# Out:
# (5596, 21)

# %%
y_train
# Out:
# 6989    0
# 560     0
# 352     0
# 5166    0
# 518     0
# 4635    0
# 3873    0
# 2980    0
# 6732    0
# 103     1
# 3239    0
# 6011    0
# 3861    0
# 6070    0
# 4109    0
# 6241    0
# 2515    0
# 100     1
# 5779    0
# 4858    0
# 2750    0
# 3051    0
# 1751    0
# 853     0
# 4781    0
# 91      1
# 425     1
# 424     1
# 5907    0
# 1815    1
#        ..
# 2882    0
# 149     1
# 206     1
# 4915    0
# 6939    0
# 5156    0
# 3666    0
# 5375    0
# 1110    1
# 5965    0
# 6275    0
# 5801    0
# 4174    0
# 92      1
# 4226    0
# 3827    0
# 5256    0
# 1930    1
# 1926    1
# 1920    1
# 1104    1
# 6592    0
# 5554    0
# 5884    0
# 134     1
# 5270    0
# 3131    0
# 114     1
# 218     0
# 1139    1
# Name: Bike Buyer, Length: 5596, dtype: int64

# %%
x_test
# Out:
# array([[ 1.,  0.,  0., ...,  1.,  1., 48.],
#        [ 1.,  0.,  0., ...,  1.,  1., 28.],
#        [ 0.,  0.,  1., ...,  8.,  2., 43.],
#        ...,
#        [ 1.,  0.,  0., ...,  2.,  1., 70.],
#        [ 1.,  0.,  0., ...,  9.,  0., 29.],
#        [ 1.,  0.,  0., ...,  9.,  1., 35.]])

# %%
y_test
# Out:
# 5130    0
# 2499    0
# 1385    0
# 760     1
# 3219    0
# 2902    0
# 3375    0
# 4433    0
# 2336    0
# 4003    0
# 6770    0
# 3693    0
# 2175    0
# 3364    0
# 1880    1
# 396     0
# 5032    0
# 4927    0
# 1644    0
# 3456    0
# 6801    0
# 2850    0
# 6111    0
# 2551    0
# 6468    0
# 6647    0
# 1067    1
# 954     1
# 2664    0
# 1516    0
#        ..
# 5428    0
# 6477    0
# 3907    0
# 824     1
# 4082    0
# 6536    0
# 4023    0
# 6099    0
# 3875    0
# 1878    0
# 5448    0
# 3801    0
# 95      0
# 22      0
# 3755    0
# 5396    0
# 1545    0
# 2471    0
# 1276    0
# 2796    0
# 3458    0
# 4582    0
# 6076    0
# 3815    0
# 4834    0
# 2271    0
# 6668    0
# 4941    0
# 3015    0
# 3459    0
# Name: Bike Buyer, Length: 1399, dtype: int64

# %%
#fitting classifier to the training set
clf=neighbors.KNeighborsClassifier()
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
#predicting the test set results
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_pred_train=clf.predict(x_train)
y_pred_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#building a confusion matrix on test and train 
from sklearn.metrics import confusion_matrix
clf_cm_test=confusion_matrix(y_test,y_pred)
clf_cm_test
# Out:
# array([[1153,   43],
#        [ 169,   34]], dtype=int64)

# %%
clf_cm_train=confusion_matrix(y_train,y_pred_train)
clf_cm_train
# Out:
# array([[4722,   79],
#        [ 552,  243]], dtype=int64)

# %%
#obtain accuracy
accuracy=clf.score(x_test,y_test)
print(accuracy)
# Out:
# 0.8484631879914224

# %%
accuracy_train=clf.score(x_train,y_train)
print(accuracy_train)
# Out:
# 0.887240886347391

# %%
#Precision score on test and train
from sklearn.metrics import precision_score
clf_precision_test=precision_score(y_test,y_pred,average='weighted')
print(clf_precision_test)
# Out:
# 0.8096810412058281

# %%
clf_precision_train=precision_score(y_train,y_pred_train,average='weighted')
print(clf_precision_train)
# Out:
# 0.8753501917904613

# %%
#recall score
from sklearn.metrics import recall_score
clf_recall_test=recall_score(y_test,y_pred,average='weighted')
print(clf_recall_test)
# Out:
# 0.8484631879914224

# %%
clf_recall_train=recall_score(y_train,y_pred_train,average='weighted')
print(clf_recall_train)
# Out:
# 0.887240886347391

# %% [markdown]
# # perform logistic regression

# %%
from sklearn.linear_model.logistic import LogisticRegression
cls=LogisticRegression(random_state=0)
lr_cls=cls.fit(x_train,y_train)

# %%
#predicting on test and train set
lr_y_test=lr_cls.predict(x_test)
lr_y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 5130    0
# 2499    0
# 1385    0
# 760     1
# 3219    0
# 2902    0
# 3375    0
# 4433    0
# 2336    0
# 4003    0
# 6770    0
# 3693    0
# 2175    0
# 3364    0
# 1880    1
# 396     0
# 5032    0
# 4927    0
# 1644    0
# 3456    0
# 6801    0
# 2850    0
# 6111    0
# 2551    0
# 6468    0
# 6647    0
# 1067    1
# 954     1
# 2664    0
# 1516    0
#        ..
# 5428    0
# 6477    0
# 3907    0
# 824     1
# 4082    0
# 6536    0
# 4023    0
# 6099    0
# 3875    0
# 1878    0
# 5448    0
# 3801    0
# 95      0
# 22      0
# 3755    0
# 5396    0
# 1545    0
# 2471    0
# 1276    0
# 2796    0
# 3458    0
# 4582    0
# 6076    0
# 3815    0
# 4834    0
# 2271    0
# 6668    0
# 4941    0
# 3015    0
# 3459    0
# Name: Bike Buyer, Length: 1399, dtype: int64

# %%
lr_y_train=lr_cls.predict(x_train)
lr_y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#building a confusion matrix on test and train 
from sklearn.metrics import confusion_matrix
lr_cm_test=confusion_matrix(y_test,lr_y_test)
lr_cm_test
# Out:
# array([[1196,    0],
#        [ 203,    0]], dtype=int64)

# %%
lr_cm_train=confusion_matrix(y_train,lr_y_train)
lr_cm_train
# Out:
# array([[4801,    0],
#        [ 795,    0]], dtype=int64)

# %%
#obtain accuracy
from sklearn.metrics import accuracy_score
lr_accu_test=accuracy_score(y_test,lr_y_test)
lr_accu_test
# Out:
# 0.8548963545389564

# %%
lr_accu_train=accuracy_score(y_train,lr_y_train)
lr_accu_train
# Out:
# 0.8579342387419585

# %% [markdown]
# # svm

# %%
from sklearn.svm import SVC
sc=SVC(kernel='rbf')
sc_classifier=sc.fit(x_train,y_train) #model building

# %%
#predicting on Test and data
svc_y_test=sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# [0 0 0 ... 0 0 0]

# %%
svc_y_train=sc_classifier.predict(x_train)   #train
print(svc_y_train)
# Out:
# [0 0 0 ... 0 0 0]

# %%
#build confusion matrix on test train
from sklearn.metrics import confusion_matrix
svc_cm_test=confusion_matrix(y_test,svc_y_test)
svc_cm_test
# Out:
# array([[1187,    9],
#        [ 190,   13]], dtype=int64)

# %%
svc_cm_train=confusion_matrix(y_train,svc_y_train)
svc_cm_train
# Out:
# array([[4792,    9],
#        [ 696,   99]], dtype=int64)

# %%
#accuracy classification score
from sklearn.metrics import accuracy_score
svc_accu_test=accuracy_score(y_test,svc_y_test)
svc_accu_test
# Out:
# 0.8577555396711937

# %%
svc_accu_train=accuracy_score(y_train,svc_y_train)
svc_accu_train
# Out:
# 0.8740171551107935

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc_clf=DecisionTreeClassifier()
dtc_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Predicting on test and train data
dtc_y_test=dtc_clf.predict(x_test)
dtc_y_test
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
dtc_y_train=dtc_clf.predict(x_train)    #train
dtc_y_train
# Out:
# array([0, 0, 0, ..., 1, 0, 1], dtype=int64)

# %%
#build confusion matrix on test train
from sklearn.metrics import confusion_matrix
dtc_cm_test=confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[1050,  146],
#        [ 128,   75]], dtype=int64)

# %%
dtc_cm_train=confusion_matrix(y_train,dtc_y_train)
dtc_cm_train
# Out:
# array([[4795,    6],
#        [  97,  698]], dtype=int64)

# %%
#accuracy classification score
from sklearn.metrics import accuracy_score
dtc_accu_test=accuracy_score(y_test,dtc_y_test)
dtc_accu_test
# Out:
# 0.8041458184417442

# %%
dtc_accu_train=accuracy_score(y_train,dtc_y_train)
dtc_accu_train
# Out:
# 0.9815939957112223

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rmf=RandomForestClassifier(max_depth=3,random_state=0)
rmf_classi=rmf.fit(x_train,y_train)

# %%
#predicting on test and train
rf_y_test=rmf_classi.predict(x_test)
rf_y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
rf_y_train=rmf_classi.predict(x_train)
rf_y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#build confusion matrix on test train
from sklearn.metrics import confusion_matrix
rf_cm_test=confusion_matrix(y_test,rf_y_test)
rf_cm_test
# Out:
# array([[1196,    0],
#        [ 203,    0]], dtype=int64)

# %%
rf_cm_train=confusion_matrix(y_train,rf_y_train)
rf_cm_train
# Out:
# array([[4801,    0],
#        [ 795,    0]], dtype=int64)

# %%
#accuracy classification score
from sklearn.metrics import accuracy_score
rf_accu_test=accuracy_score(y_test,rf_y_test)
rf_accu_test
# Out:
# 0.8548963545389564

# %%
rf_accu_train=accuracy_score(y_train,rf_y_train)
rf_accu_train
# Out:
# 0.8579342387419585

# %%
#Precision score on test and train
from sklearn.metrics import precision_score
rf_precision_test=precision_score(y_test,rf_y_test,average='weighted')
print(rf_precision_test)
# Out:
# 0.7308477770039971
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
rf_precision_train=precision_score(y_train,rf_y_train,average='weighted')
print(rf_precision_train)
# Out:
# 0.7360511580057438
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#recall score
from sklearn.metrics import recall_score
rf_recall_test=recall_score(y_test,rf_y_test,average='weighted')
print(rf_recall_test)
# Out:
# 0.8548963545389564

# %%
rf_recall_train=recall_score(y_train,rf_y_train,average='weighted')
print(rf_recall_train)
# Out:
# 0.8579342387419585

# %% [markdown]
# # AdaBoost

# %%
#perform AdaBoost
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
seed=50
num_trees=1000
kfold=model_selection.KFold(n_splits=10,random_state=seed)
model=AdaBoostClassifier(n_estimators=num_trees,random_state=seed)
results=model_selection.cross_val_score(model,x_train,y_train,cv=kfold)

# %%
print(results)
# Out:
# [0.8625     0.84642857 0.86071429 0.83928571 0.85714286 0.87857143
#  0.85330948 0.88908766 0.83899821 0.86940966]

# %%
print(results.mean())
# Out:
# 0.8595447866087401

# %%
#Test new data
example_measures=np.array(['Single','Female',50000,2,'Partial College','Clerical','Yes',0,7,'Pacific',35])
example_measures=example_measures.reshape(-1,1)

# %%
#predict new data
#prediction=dtc_clf.predict(example_measures)

# %% [markdown]
# # Multi Linear Regression

# %%
#Fitting Multiple Linear regression to the Training set
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Predicting the Test Set results
y_mlr_pred=reg.predict(x_test)
y_mlr_pred
# Out:
# array([0.07668418, 0.17589302, 0.21879096, ..., 0.082563  , 0.16826843,
#        0.23370693])

# %%
y_test
# Out:
# 5130    0
# 2499    0
# 1385    0
# 760     1
# 3219    0
# 2902    0
# 3375    0
# 4433    0
# 2336    0
# 4003    0
# 6770    0
# 3693    0
# 2175    0
# 3364    0
# 1880    1
# 396     0
# 5032    0
# 4927    0
# 1644    0
# 3456    0
# 6801    0
# 2850    0
# 6111    0
# 2551    0
# 6468    0
# 6647    0
# 1067    1
# 954     1
# 2664    0
# 1516    0
#        ..
# 5428    0
# 6477    0
# 3907    0
# 824     1
# 4082    0
# 6536    0
# 4023    0
# 6099    0
# 3875    0
# 1878    0
# 5448    0
# 3801    0
# 95      0
# 22      0
# 3755    0
# 5396    0
# 1545    0
# 2471    0
# 1276    0
# 2796    0
# 3458    0
# 4582    0
# 6076    0
# 3815    0
# 4834    0
# 2271    0
# 6668    0
# 4941    0
# 3015    0
# 3459    0
# Name: Bike Buyer, Length: 1399, dtype: int64

# %%
    import statsmodels.formula.api as sm
model=sm.ols(formula='bb~mar+Gender+year+ed+age+car+hom+com+Occupation+Children+Region',data=bikebuyer).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     bb   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     16.57
# Date:                Wed, 30 May 2018   Prob (F-statistic):           1.69e-51
# Time:                        01:54:17   Log-Likelihood:                -2430.3
# No. Observations:                6995   AIC:                             4899.
# Df Residuals:                    6976   BIC:                             5029.
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...
